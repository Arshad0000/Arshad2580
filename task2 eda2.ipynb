# %%
# Importing the pandas library and aliasing it as 'pd' for convenience
import pandas as pd
#pandas is a powerful data manipulation library. It provides data structures like DataFrame and Series, making it easy to work with structured data.
#Example use: Reading & manipulating datasets, handling missing data, filtering, grouping, & transforming data.

# Importing the numpy library and aliasing it as 'np' for convenience
import numpy as np
#numpy is a library for numerical operations. It provides support for large, multi-dimensional arrays and matrices, along with mathematical functions.
#Example use: Numerical operations on arrays, linear algebra operations, mathematical functions, random number generation

# Importing the matplotlib.pyplot module and aliasing it as 'plt' for convenience
import matplotlib.pyplot as plt
#matplotlib is a versatile plotting library. pyplot is a module within matplotlib that provides a MATLAB-like interface for creating static, interactive, and animated plots.
#Example use: Creating line plots, scatter plots, bar pEDA, or Exploratory Data Analysis involves examining and visualizing the characteristics of a dataset to gain insights, identify patterns, and inform subsequent modeling decisions lots, histograms, and customizing visualizations.

# Importing the seaborn library and aliasing it as 'sns' for convenience
import seaborn as sns
#seaborn is a statistical data visualization library that works on top of matplotlib. It simplifies the creation of aesthetically pleasing visualizations.
#Example use: Creating complex visualizations with less code, statistical plots, heatmaps, pair plots, and enhancing the style of matplotlib plots.

# %%
# Load your dataset
data = pd.read_csv('/content/Electric_Vehicle_Population_Data.csv')

# %%
# Display basic information about the dataset
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34882 entries, 0 to 34881
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         34882 non-null  object
#  1   County                                             34881 non-null  object
#  2   City                                               34881 non-null  object
#  3   State                                              34882 non-null  object
#  4   Postal Code                                        34881 non-null  float64
#  5   Model Year                                         34882 non-null  int64
#  6   Make                                               34882 non-null  object
#  7   Model                                              34882 non-null  object
#  8   Electric Vehicle Type                              34882 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  34882 non-null  object
#  10  Electric Range                                     34882 non-null  int64
#  11  Base MSRP                                          34882 non-null  int64
#  12  Legislative District                               34881 non-null  float64
#  13  DOL Vehicle ID                                     34882 non-null  int64
#  14  Vehicle Location                                   34881 non-null  object
#  15  Electric Utility                                   34880 non-null  object
#  16  2020 Census Tract                                  34880 non-null  float64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 4.5+ MB
# None

# %%
# Display summary statistics
print(data.describe())
# Out:
#         Postal Code    Model Year  Electric Range      Base MSRP  \
# count  34881.000000  34882.000000    34882.000000   34882.000000
# mean   98173.962788   2020.394587       62.977983    1155.082134
# std      209.448553      2.937412       94.377272    8536.359927
# min    98001.000000   1998.000000        0.000000       0.000000
# 25%    98034.000000   2018.000000        0.000000       0.000000
# 50%    98109.000000   2021.000000        6.000000       0.000000
# 75%    98188.000000   2023.000000       84.000000       0.000000
# max    99362.000000   2024.000000      337.000000  184400.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count          34881.000000    3.488200e+04       3.488000e+04
# mean              32.268198    2.163777e+08       5.303347e+10
# std               14.519451    7.876723e+07       1.161823e+07
# min                1.000000    1.100570e+05       5.300796e+10
# 25%               20.000000    1.789501e+08       5.303301e+10
# 50%               36.000000    2.239951e+08       5.303302e+10
# 75%               45.000000    2.473874e+08       5.303303e+10
# max               49.000000    4.789259e+08       5.307794e+10

# %%
# Display the first 4 rows of the dataset
data.head(4)
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year    Make  \
# 0  5YJYGDEF5L  Thurston      Lacey    WA      98516.0        2020   TESLA
# 1  1N4BZ1CP1K      King  Sammamish    WA      98074.0        2019  NISSAN
# 2  5YJXCDE28G      King       Kent    WA      98031.0        2016   TESLA
# 3  JHMZC5F37M    Kitsap    Poulsbo    WA      98370.0        2021   HONDA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL Y          Battery Electric Vehicle (BEV)
# 1     LEAF          Battery Electric Vehicle (BEV)
# 2  MODEL X          Battery Electric Vehicle (BEV)
# 3  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             291
# 1           Clean Alternative Fuel Vehicle Eligible             150
# 2           Clean Alternative Fuel Vehicle Eligible             200
# 3           Clean Alternative Fuel Vehicle Eligible              47
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  22.0       124535071
# 1          0                  45.0       102359449
# 2          0                  33.0       228682037
# 3          0                  23.0       171566447
#
#                   Vehicle Location  \
# 0  POINT (-122.7474291 47.0821119)
# 1  POINT (-122.0313266 47.6285782)
# 2  POINT (-122.2012521 47.3931814)
# 3     POINT (-122.64177 47.737525)
#
#                                 Electric Utility  2020 Census Tract
# 0                         PUGET SOUND ENERGY INC       5.306701e+10
# 1  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 2  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 3                         PUGET SOUND ENERGY INC       5.303509e+10

# %%
# Display the last 2 rows of the dataset
data.tail(2)
# Out:
#        VIN (1-10) County         City State  Postal Code  Model Year   Make  \
# 34880  KNDCR3L19P   King       Renton    WA      98057.0        2023    KIA
# 34881  7SAYGDEE8P   King  Federal Way    WA      98003.0        2023  TESLA
#
#          Model           Electric Vehicle Type  \
# 34880     NIRO  Battery Electric Vehicle (BEV)
# 34881  MODEL Y  Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 34880  Eligibility unknown as battery range has not b...               0
# 34881  Eligibility unknown as battery range has not b...               0
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 34880          0                  11.0       238519221
# 34881          0                  30.0       259013772
#
#                     Vehicle Location  \
# 34880  POINT (-122.21024 47.4797047)
# 34881                        POINT (
#
#                                     Electric Utility  2020 Census Tract
# 34880  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 34881                                            NaN                NaN

# %%
#Check for Duplication
data.nunique()
# Out:
# VIN (1-10)                                            6393
# County                                                  19
# City                                                   142
# State                                                    2
# Postal Code                                            208
# Model Year                                              19
# Make                                                    38
# Model                                                  126
# Electric Vehicle Type                                    2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility        3
# Electric Range                                          98
# Base MSRP                                               28
# Legislative District                                    41
# DOL Vehicle ID                                       34882
# Vehicle Location                                       209
# Electric Utility                                        25
# 2020 Census Tract                                      948
# dtype: int64

# %%
#Missing Values Calculation
data.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               1
# City                                                 1
# State                                                0
# Postal Code                                          1
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 1
# DOL Vehicle ID                                       0
# Vehicle Location                                     1
# Electric Utility                                     2
# 2020 Census Tract                                    2
# dtype: int64

# %%
#calculate the percentage of missing values in each column
(data.isnull().sum()/(len(data)))*100
# Out:
# VIN (1-10)                                           0.000000
# County                                               0.002867
# City                                                 0.002867
# State                                                0.000000
# Postal Code                                          0.002867
# Model Year                                           0.000000
# Make                                                 0.000000
# Model                                                0.000000
# Electric Vehicle Type                                0.000000
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000
# Electric Range                                       0.000000
# Base MSRP                                            0.000000
# Legislative District                                 0.002867
# DOL Vehicle ID                                       0.000000
# Vehicle Location                                     0.002867
# Electric Utility                                     0.005734
# 2020 Census Tract                                    0.005734
# dtype: float64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %%
#Univariate Analysis
# Histogram for numeric variables
data.hist(figsize=(12, 10))
plt.show()

# %%
# Choose a variable to analyze (replace 'YourVariable' with the actual column name)
variable_to_analyze = 'Electric Range'

# %%
# Check for missing values
missing_values = data[variable_to_analyze].isnull().sum()
print(f"Missing values in {variable_to_analyze}: {missing_values}")
# Out:
# Missing values in Electric Range: 0

# %%
# Summary statistics
summary_stats = data[variable_to_analyze].describe()
print(f"Summary statistics for {variable_to_analyze}:\n{summary_stats}")
# Out:
# Summary statistics for Electric Range:
# count    34882.000000
# mean        62.977983
# std         94.377272
# min          0.000000
# 25%          0.000000
# 50%          6.000000
# 75%         84.000000
# max        337.000000
# Name: Electric Range, dtype: float64

# %%
# Visualize the distribution of the variable
plt.figure(figsize=(10, 6))
data[variable_to_analyze].hist(bins=20, edgecolor='black', grid=False)
plt.title(f'Distribution of {variable_to_analyze}')
plt.xlabel(variable_to_analyze)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Bivariate Analysis** for Numerical Variables (e.g., Electric Range vs. Base MSRP):

# %%
import seaborn as sns

# Assuming 'data' is your DataFrame
# Choose two numerical variables for analysis
variable1 = 'Electric Range'
variable2 = 'Base MSRP'

# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x=variable1, y=variable2)
plt.title(f'Scatter plot between {variable1} and {variable2}')
plt.show()

# Correlation matrix
correlation_matrix = data[[variable1, variable2]].corr()
print(f"Correlation matrix between {variable1} and {variable2}:\n{correlation_matrix}")
# Out:
# Correlation matrix between Electric Range and Base MSRP:
#                 Electric Range  Base MSRP
# Electric Range        1.000000   0.115377
# Base MSRP             0.115377   1.000000

# %% [markdown]
# **Bivariate Analysis for Categorical Variables** (e.g., City vs. Electric Vehicle Type):

# %%
# Choose two categorical variables for analysis
variable1 = 'Model Year'
variable2 = 'Electric Vehicle Type'

# Create a contingency table
contingency_table = pd.crosstab(data[variable1], data[variable2])

# Plot a heatmap for the contingency table
plt.figure(figsize=(12, 8))
sns.heatmap(contingency_table, annot=True, fmt='d', cmap='viridis')
plt.title(f'Contingency Table: {variable1} vs. {variable2}')
plt.xlabel(variable2)
plt.ylabel(variable1)
plt.show()

# %% [markdown]
# **Multivariate analysis** involves analyzing the relationships between multiple variables in your dataset. One common technique is to use pair plots for numerical variables or parallel coordinate plots for a mix of numerical and categorical variables

# %%
# Select relevant numerical variables for pair plot
numerical_variables = ['Electric Range', 'Base MSRP']

# Select relevant categorical variables for hue in pair plot (optional)
categorical_variable = 'Electric Vehicle Type'

# Create a pair plot
sns.pairplot(data, vars=numerical_variables, hue=categorical_variable, height=3)
plt.suptitle('Pair Plot of Numerical Variables with Hue for Categorical Variable', y=1.02)
plt.show()

# %% [markdown]
# **TASK 3**

# %% [markdown]
# **Interquartile Range (IQR)**: Measures the statistical dispersion of the data, providing a robust measure of variability. It is calculated as the difference between the third quartile (Q3) and the first quartile (Q1).

# %% [markdown]
# **Skewness:** Measures the asymmetry of the probability distribution of a real-valued random variable. A skewness value of 0 indicates a perfectly symmetrical distribution.

# %% [markdown]
# **Kurtosis:** Measures the tailedness or sharpness of the peak of a distribution. A higher kurtosis value indicates heavier tails and a sharper peak compared to a normal distribution.

# %% [markdown]
# **Handling Outliers using Z-Score:** Identifies outliers by calculating how many standard deviations a data point is from the mean. Points with a z-score greater than a threshold (commonly 3) are considered outliers.

# %% [markdown]
# **Handling Outliers using IQR:** Identifies outliers by comparing data points to the interquartile range. Points outside a certain range (typically 1.5 times IQR) are considered outliers.

# %%
import numpy as np
import pandas as pd
from scipy.stats import iqr, skew, kurtosis, zscore
from sklearn.preprocessing import StandardScaler

# %%
#loading dataset
df = pd.read_csv('/content/Electric_Vehicle_Population_Data.csv')

# %%
# Extract the numeric columns for analysis
numeric_columns = df.select_dtypes(include=np.number)

# %%
# Display basic information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113113 entries, 0 to 113112
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         113113 non-null  object
#  1   County                                             113112 non-null  object
#  2   City                                               113112 non-null  object
#  3   State                                              113113 non-null  object
#  4   Postal Code                                        113112 non-null  float64
#  5   Model Year                                         113113 non-null  int64
#  6   Make                                               113113 non-null  object
#  7   Model                                              113113 non-null  object
#  8   Electric Vehicle Type                              113113 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  113113 non-null  object
#  10  Electric Range                                     113112 non-null  float64
#  11  Base MSRP                                          113112 non-null  float64
#  12  Legislative District                               113054 non-null  float64
#  13  DOL Vehicle ID                                     113112 non-null  float64
#  14  Vehicle Location                                   113109 non-null  object
#  15  Electric Utility                                   113111 non-null  object
#  16  2020 Census Tract                                  113111 non-null  float64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 14.7+ MB
# None

# %%
# Display summary statistics
print(df.describe())
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  113112.000000  113113.000000   113112.000000  113112.000000
# mean    98203.433137    2020.272497       63.789677    1209.627758
# std      1231.993157       2.992012       94.553967    8952.354338
# min      6355.000000    1998.000000        0.000000       0.000000
# 25%     98042.000000    2018.000000        0.000000       0.000000
# 50%     98115.000000    2021.000000       13.000000       0.000000
# 75%     98310.000000    2023.000000       84.000000       0.000000
# max     99403.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         113054.000000    1.131120e+05       1.131110e+05
# mean              30.527005    2.153499e+08       5.302131e+10
# std               14.642613    7.946937e+07       8.109701e+08
# min                1.000000    4.777000e+03       1.081042e+09
# 25%               18.000000    1.756753e+08       5.303301e+10
# 50%               35.000000    2.210037e+08       5.303303e+10
# 75%               43.000000    2.493425e+08       5.303509e+10
# max               49.000000    4.789346e+08       5.307794e+10

# %%
# Calculating IQR for each column
Q1 = df.quantile(0.25, numeric_only=True)
Q3 = df.quantile(0.75, numeric_only=True)
IQR = Q3 - Q1

# Identify and remove outliers
outliers = ((df.lt(Q1 - 1.5 * IQR)) | (df.gt(Q3 + 1.5 * IQR))).any(axis=1)
df_no_outliers = df[~outliers]

# %%
# Print IQR values
print("Q1:\n", Q1)
print("Q3:\n", Q3)
print("IQR:\n", IQR)

# Print outliers
print("Outliers:\n", outliers)

# Print DataFrame without outliers
print("DataFrame without outliers:\n", df_no_outliers)
# Out:
# Q1:
#  Postal Code             9.804200e+04
# Model Year              2.018000e+03
# Electric Range          0.000000e+00
# Base MSRP               0.000000e+00
# Legislative District    1.800000e+01
# DOL Vehicle ID          1.756753e+08
# 2020 Census Tract       5.303301e+10
# Name: 0.25, dtype: float64
# Q3:
#  Postal Code             9.831000e+04
# Model Year              2.023000e+03
# Electric Range          8.400000e+01
# Base MSRP               0.000000e+00
# Legislative District    4.300000e+01
# DOL Vehicle ID          2.493425e+08
# 2020 Census Tract       5.303509e+10
# Name: 0.75, dtype: float64
# IQR:
#  Postal Code                  268.0
# Model Year                     5.0
# Electric Range                84.0
# Base MSRP                      0.0
# Legislative District          25.0
# DOL Vehicle ID          73667156.5
# 2020 Census Tract        2083200.0
# dtype: float64
# Outliers:
#  0          True
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 113108     True
# 113109     True
# 113110     True
# 113111     True
# 113112    False
# Length: 113113, dtype: bool
# DataFrame without outliers:
#          VIN (1-10)     County          City State  Postal Code  Model Year  \
# 1       1N4BZ1CP1K       King     Sammamish    WA      98074.0        2019
# 2       5YJXCDE28G       King          Kent    WA      98031.0        2016
# 3       JHMZC5F37M     Kitsap       Poulsbo    WA      98370.0        2021
# 6       WAUUPBFF7H       King       Seattle    WA      98136.0        2017
# 8       5YJXCAE2XG     Kitsap     Bremerton    WA      98310.0        2016
# ...            ...        ...           ...   ...          ...         ...
# 113096  1N4AZ0CP8D       King        Auburn    WA      98001.0        2013
# 113104  5YJSA1E27H       King       Seattle    WA      98109.0        2017
# 113105  7SAYGDEE2P       King          Kent    WA      98042.0        2023
# 113106  1FTVW1EVXP       King    Snoqualmie    WA      98065.0        2023
# 113112  JTMABABA9P  Jefferson  Port Hadlock    WA      98339.0        2023
#
#           Make     Model                   Electric Vehicle Type  \
# 1       NISSAN      LEAF          Battery Electric Vehicle (BEV)
# 2        TESLA   MODEL X          Battery Electric Vehicle (BEV)
# 3        HONDA   CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 6         AUDI        A3  Plug-in Hybrid Electric Vehicle (PHEV)
# 8        TESLA   MODEL X          Battery Electric Vehicle (BEV)
# ...        ...       ...                                     ...
# 113096  NISSAN      LEAF          Battery Electric Vehicle (BEV)
# 113104   TESLA   MODEL S          Battery Electric Vehicle (BEV)
# 113105   TESLA   MODEL Y          Battery Electric Vehicle (BEV)
# 113106    FORD     F-150          Battery Electric Vehicle (BEV)
# 113112  SUBARU  SOLTERRA          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 1                 Clean Alternative Fuel Vehicle Eligible           150.0
# 2                 Clean Alternative Fuel Vehicle Eligible           200.0
# 3                 Clean Alternative Fuel Vehicle Eligible            47.0
# 6                   Not eligible due to low battery range            16.0
# 8                 Clean Alternative Fuel Vehicle Eligible           200.0
# ...                                                   ...             ...
# 113096            Clean Alternative Fuel Vehicle Eligible            75.0
# 113104            Clean Alternative Fuel Vehicle Eligible           210.0
# 113105  Eligibility unknown as battery range has not b...             0.0
# 113106  Eligibility unknown as battery range has not b...             0.0
# 113112                                           Eligibil             NaN
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 1             0.0                  45.0     102359449.0
# 2             0.0                  33.0     228682037.0
# 3             0.0                  23.0     171566447.0
# 6             0.0                  34.0     193332373.0
# 8             0.0                  23.0     103165100.0
# ...           ...                   ...             ...
# 113096        0.0                  30.0     234305046.0
# 113104        0.0                  36.0     347950235.0
# 113105        0.0                  47.0     238084619.0
# 113106        0.0                   5.0     245711826.0
# 113112        NaN                   NaN             NaN
#
#                        Vehicle Location  \
# 1       POINT (-122.0313266 47.6285782)
# 2       POINT (-122.2012521 47.3931814)
# 3          POINT (-122.64177 47.737525)
# 6           POINT (-122.388675 47.5415)
# 8         POINT (-122.611365 47.575195)
# ...                                 ...
# 113096  POINT (-122.2849393 47.3384055)
# 113104     POINT (-122.34848 47.632405)
# 113105     POINT (-122.111625 47.36078)
# 113106  POINT (-121.8740496 47.5345546)
# 113112                              NaN
#
#                                      Electric Utility  2020 Census Tract
# 1       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 2       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 3                              PUGET SOUND ENERGY INC       5.303509e+10
# 6        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 8                              PUGET SOUND ENERGY INC       5.303508e+10
# ...                                               ...                ...
# 113096  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 113104   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 113105  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 113106  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 113112                                            NaN                NaN
#
# [59258 rows x 17 columns]

# %%
# Calculate skewness and kurtosis for each column
skewness = df.skew()
kurt = df.kurtosis()

print("Skewness:\n", skewness)
print("\nKurtosis:\n", kurt)
# Out:
# Skewness:
#  Postal Code            -58.334395
# Model Year              -1.063822
# Electric Range           1.315654
# Base MSRP               14.234119
# Legislative District    -0.577694
# DOL Vehicle ID           0.738397
# 2020 Census Tract      -53.262836
# dtype: float64
#
# Kurtosis:
#  Postal Code             3693.433035
# Model Year                 0.426713
# Electric Range             0.221423
# Base MSRP                752.838824
# Legislative District      -0.951068
# DOL Vehicle ID             3.341270
# 2020 Census Tract       2928.098293
# dtype: float64
# <ipython-input-11-791e5b85a241>:2: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   skewness = df.skew()
# <ipython-input-11-791e5b85a241>:3: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   kurt = df.kurtosis()

# %%
# Standardize numerical columns using StandardScaler
numerical_columns = df.select_dtypes(include=[np.number]).columns
scaler = StandardScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting boxplots before and after handling outliers
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(data=df)
plt.title("Boxplot Before Handling Outliers")
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
sns.boxplot(data=df_no_outliers)
plt.title("Boxplot After Handling Outliers")
plt.xticks(rotation=90)

plt.show()

# %%
# Plotting skewness and kurtosis
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.barplot(x=skewness.index, y=skewness.values)
plt.title("Skewness")
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
sns.barplot(x=kurt.index, y=kurt.values)
plt.title("Kurtosis")

plt.xticks(rotation=45)
plt.show()

# %%
# Plotting histograms of standardized numerical columns
df[numerical_columns].hist(figsize=(12, 8), bins=20)
plt.suptitle("Histograms of Standardized Numerical Columns", y=1.02)
plt.show()

# %% [markdown]
# This plot illustrates how the data distribution has changed after standardization.
